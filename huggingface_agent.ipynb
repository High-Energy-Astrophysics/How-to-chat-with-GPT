# %%
from transformers import OpenAiAgent

OPENAI_API_KEY = open("/home/plsek/Documents/Keys/openai.txt").read().strip("\n")
agent = OpenAiAgent(model="text-davinci-003", api_key=OPENAI_API_KEY)

# %%
agent.chat("What is the distance of galaxy NGC4649?")
# Out:
# ==Explanation from the agent==
# I will use the tool `text_qa` to answer the question.
#
#
# ==Code generated by the agent==
# text = "Galaxy NGC4649 is a spiral galaxy located in the constellation Virgo. It is about 55 million light-years away from Earth."
# answer = text_qa(text=text, question="What is the distance of galaxy NGC4649?")
# print(f"The answer is {answer}.")
#
#
# ==Result==
# The answer is 55 million light-years.
# /space/LLMs/HF/lib/python3.11/site-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# '55 million light-years'

# %%
agent.run("Draw me a picture of rivers and lakes.", remote=True)
# Out:
# ==Explanation from the agent==
# I will use the following  tool: `image_generator` to generate an image according to the prompt.
#
#
# ==Code generated by the agent==
# image = image_generator(prompt="Draw me a picture of rivers and lakes.")
#
#
# ==Result==
# A new version of the following files was downloaded from https://huggingface.co/space/huggingface-tools/text-to-image:
# - text_to_image.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %% [markdown]
# ## **Speak**

# %%
agent.run("Read the following text out loud", text="What time is it?", remote=True)
# Out:
# ==Explanation from the agent==
# I will use the following  tool: `text_reader` to read the text out loud.
#
#
# ==Code generated by the agent==
# audio_text = text_reader(text)
#
#
# ==Result==
# ...
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset cmu-arctic-xvectors downloaded and prepared to /home/plsek/.cache/huggingface/datasets/Matthijs___cmu-arctic-xvectors/default/0.0.1/a62fea1f9415e240301ea0042ffad2a3aadf4d1caa7f9a8d9512d631723e781f. Subsequent calls will reuse this data.
# tensor([-9.2181e-04, -7.1193e-04, -1.1979e-03,  ...,  8.5835e-06,
#         -2.8653e-04, -1.2810e-04])
